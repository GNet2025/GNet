# %%
import torch
import numpy as np
import time
import os
from utils import HDDataset
from model import BModel
from torchvision import datasets, transforms
import scipy
from encoder import RandomFourierEncoder
import main2_fmnist 
import importlib
importlib.reload(main2_fmnist)
import csv
from scipy.io import savemat, loadmat
from torch.utils.data import DataLoader, Subset, TensorDataset

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
gorder = 2
dim = 10000
gamma = 0.3
lr = 0.01
classes = 10
channels = 3
epochs = 3
train = main2_fmnist.train
test = main2_fmnist.test

# %%
trainset = datasets.MNIST(root='../../Data', train=True, download=True, transform=transforms.ToTensor())
testset = datasets.MNIST(root='../../Data', train=False, download=True, transform=transforms.ToTensor())
n_splits = 20
split_size = len(testset) // n_splits
accuracies1 = np.zeros((11, n_splits))
hyperdims = loadmat('../EHDGNet_MNIST_nHD.mat')['EHDGNet_MNIST_nHD']
hyperdims = np.mean(hyperdims, axis=1, dtype=int)
print(hyperdims)
input_dim = torch.prod(torch.tensor(list(trainset[0][0].size())))
print(input_dim)
for i, nHDC in enumerate(hyperdims):
    print(f'nHDC: {nHDC} ------------')
    encoder = RandomFourierEncoder(input_dim, gamma, gorder, output_dim=nHDC)
    encoder.build_item_mem()
    train_hd, y_train = encoder.encode_data_extract_labels(trainset)
    train_dataset = HDDataset(train_hd, y_train)
    trainloader = DataLoader(train_dataset, batch_size=1024, shuffle=True, pin_memory=True, num_workers=2)
    for split_idx in range(n_splits):
        # Test
        print(f'Split Index: {split_idx+1}')
        start_idx = split_idx * split_size
        end_idx = start_idx + split_size
        split_subset = Subset(testset, range(start_idx, end_idx))
        test_hd, y_test = encoder.encode_data_extract_labels(split_subset)
        test_dataset = HDDataset(test_hd, y_test)
        testloader = DataLoader(test_dataset, batch_size=512, shuffle=False, pin_memory=True, num_workers=2)
        accuracies1[i, split_idx] = train(trainloader, testloader, lr, nHDC)
        del testloader
        del test_dataset
        del test_hd
        
    del train_hd
    del trainloader
    del train_dataset
    print(f'nHDC: {nHDC} ----------- Finished')
    print(f'Average Accuracy for nHDC={nHDC}: {np.mean(accuracies1[i, :])}')
# Out:
# [ 5000  6000  7000  8000  9000 10000 11000 11750 12750 13750 14750]
# tensor(784)
# nHDC: 5000 ------------
# the threshold to discretize fourier features to group elements tensor([0.])
# Split Index: 1
# Split Index: 2
# Split Index: 3
# Split Index: 4
# Split Index: 5
# Split Index: 6
# Split Index: 7
# Split Index: 8
# Split Index: 9
# Split Index: 10
# Split Index: 11
# Split Index: 12
# Split Index: 13
# Split Index: 14
# Split Index: 15
# Split Index: 16
# Split Index: 17
# Split Index: 18
# Split Index: 19
# Split Index: 20
# nHDC: 5000 ----------- Finished
# Average Accuracy for nHDC=5000: 86.44999999999999
# nHDC: 6000 ------------
# the threshold to discretize fourier features to group elements tensor([0.])
# Split Index: 1
# Split Index: 2
# Split Index: 3
# Split Index: 4
# Split Index: 5
# Split Index: 6
# Split Index: 7
# Split Index: 8
# Split Index: 9
# Split Index: 10
# Split Index: 11
# Split Index: 12
# Split Index: 13
# Split Index: 14
# Split Index: 15
# Split Index: 16
# Split Index: 17
# Split Index: 18
# Split Index: 19
# Split Index: 20
# nHDC: 6000 ----------- Finished
# Average Accuracy for nHDC=6000: 91.85
# nHDC: 7000 ------------
# the threshold to discretize fourier features to group elements tensor([0.])
# Split Index: 1
# Split Index: 2
# Split Index: 3
# Split Index: 4
# Split Index: 5
# Split Index: 6
# Split Index: 7
# Split Index: 8
# Split Index: 9
# Split Index: 10
# Split Index: 11
# Split Index: 12
# Split Index: 13
# Split Index: 14
# Split Index: 15
# Split Index: 16
# Split Index: 17
# Split Index: 18
# Split Index: 19
# Split Index: 20
# nHDC: 7000 ----------- Finished
# Average Accuracy for nHDC=7000: 94.02
# nHDC: 8000 ------------
# the threshold to discretize fourier features to group elements tensor([0.])
# Split Index: 1
# Split Index: 2
# Split Index: 3
# Split Index: 4
# Split Index: 5
# Split Index: 6
# Split Index: 7
# Split Index: 8
# Split Index: 9
# Split Index: 10
# Split Index: 11
# Split Index: 12
# Split Index: 13
# Split Index: 14
# Split Index: 15
# Split Index: 16
# Split Index: 17
# Split Index: 18
# Split Index: 19
# Split Index: 20
# nHDC: 8000 ----------- Finished
# Average Accuracy for nHDC=8000: 91.67
# nHDC: 9000 ------------
# the threshold to discretize fourier features to group elements tensor([0.])
# Split Index: 1
# Split Index: 2
# Split Index: 3
# Split Index: 4
# Split Index: 5
# Split Index: 6
# Split Index: 7
# Split Index: 8
# Split Index: 9
# Split Index: 10
# Split Index: 11
# Split Index: 12
# Split Index: 13
# Split Index: 14
# Split Index: 15
# Split Index: 16
# Split Index: 17
# Split Index: 18
# Split Index: 19
# Split Index: 20
# nHDC: 9000 ----------- Finished
# Average Accuracy for nHDC=9000: 93.83000000000001
# nHDC: 10000 ------------
# the threshold to discretize fourier features to group elements tensor([0.])
# Split Index: 1
# Split Index: 2
# Split Index: 3
# Split Index: 4
# Split Index: 5
# Split Index: 6
# Split Index: 7
# Split Index: 8
# Split Index: 9
# Split Index: 10
# Split Index: 11
# Split Index: 12
# Split Index: 13
# Split Index: 14
# Split Index: 15
# Split Index: 16
# Split Index: 17
# Split Index: 18
# Split Index: 19
# Split Index: 20
# nHDC: 10000 ----------- Finished
# Average Accuracy for nHDC=10000: 94.44
# nHDC: 11000 ------------
# the threshold to discretize fourier features to group elements tensor([0.])
# Split Index: 1
# Split Index: 2
# Split Index: 3
# Split Index: 4
# Split Index: 5
# Split Index: 6
# Split Index: 7
# Split Index: 8
# Split Index: 9
# Split Index: 10
# Split Index: 11
# Split Index: 12
# Split Index: 13
# Split Index: 14
# Split Index: 15
# Split Index: 16
# Split Index: 17
# Split Index: 18
# Split Index: 19
# Split Index: 20
# nHDC: 11000 ----------- Finished
# Average Accuracy for nHDC=11000: 94.66
# nHDC: 11750 ------------
# the threshold to discretize fourier features to group elements tensor([0.])
# Split Index: 1
# Split Index: 2
# Split Index: 3
# Split Index: 4
# Split Index: 5
# Split Index: 6
# Split Index: 7
# Split Index: 8
# Split Index: 9
# Split Index: 10
# Split Index: 11
# Split Index: 12
# Split Index: 13
# Split Index: 14
# Split Index: 15
# Split Index: 16
# Split Index: 17
# Split Index: 18
# Split Index: 19
# Split Index: 20
# nHDC: 11750 ----------- Finished
# Average Accuracy for nHDC=11750: 94.28
# nHDC: 12750 ------------
# the threshold to discretize fourier features to group elements tensor([0.])
# Split Index: 1
# Split Index: 2
# Split Index: 3
# Split Index: 4
# Split Index: 5
# Split Index: 6
# Split Index: 7
# Split Index: 8
# Split Index: 9
# Split Index: 10
# Split Index: 11
# Split Index: 12
# Split Index: 13
# Split Index: 14
# Split Index: 15
# Split Index: 16
# Split Index: 17
# Split Index: 18
# Split Index: 19
# Split Index: 20
# nHDC: 12750 ----------- Finished
# Average Accuracy for nHDC=12750: 94.43999999999998
# nHDC: 13750 ------------
# the threshold to discretize fourier features to group elements tensor([0.])
# Split Index: 1
# Split Index: 2
# Split Index: 3
# Split Index: 4
# Split Index: 5
# Split Index: 6
# Split Index: 7
# Split Index: 8
# Split Index: 9
# Split Index: 10
# Split Index: 11
# Split Index: 12
# Split Index: 13
# Split Index: 14
# Split Index: 15
# Split Index: 16
# Split Index: 17
# Split Index: 18
# Split Index: 19
# Split Index: 20
# nHDC: 13750 ----------- Finished
# Average Accuracy for nHDC=13750: 95.37
# nHDC: 14750 ------------
# the threshold to discretize fourier features to group elements tensor([0.])
# Split Index: 1
# Split Index: 2
# Split Index: 3
# Split Index: 4
# Split Index: 5
# Split Index: 6
# Split Index: 7
# Split Index: 8
# Split Index: 9
# Split Index: 10
# Split Index: 11
# Split Index: 12
# Split Index: 13
# Split Index: 14
# Split Index: 15
# Split Index: 16
# Split Index: 17
# Split Index: 18
# Split Index: 19
# Split Index: 20
# nHDC: 14750 ----------- Finished
# Average Accuracy for nHDC=14750: 95.58000000000001

# %%
np.mean(accuracies1, axis=1)
# Out:
# array([86.45, 91.85, 94.02, 91.67, 93.83, 94.44, 94.66, 94.28, 94.44,
#        95.37, 95.58])

# %%
savemat('RFFHDC_MNIST.mat', {'RFFHDC_MNIST': accuracies1})
